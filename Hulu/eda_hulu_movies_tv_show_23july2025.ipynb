# %% [markdown]
# ## Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## File

# %%
url = 'https://raw.githubusercontent.com/albvieiraa/EDA-Streamings/refs/heads/main/datasets/hulu_titles.csv'

# %%
df_hulu = pd.read_csv(url)
df_hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# 0  ​Comedian Ricky Velez bares it all with his ho...
# 1  Mark, a low end South London hitman recently r...
# 2  A hardened Arizona rancher tries to protect an...
# 3  A forest ranger and two survivalists with a cu...
# 4  Mankind's earliest settlers on the Martian fro...

# %%
df_hulu.tail(3)
# Out:
#      show_id     type                title director  cast         country  \
# 3070   s3071  TV Show            The Fades      NaN   NaN  United Kingdom
# 3071   s3072  TV Show    The Twilight Zone      NaN   NaN   United States
# 3072   s3073  TV Show  Tokyo Magnitude 8.0      NaN   NaN           Japan
#
#      date_added  release_year rating   duration  \
# 3070        NaN          2011  TV-14   1 Season
# 3071        NaN          1959  TV-PG  5 Seasons
# 3072        NaN          2009  TV-14   1 Season
#
#                                    listed_in  \
# 3070  Horror, International, Science Fiction
# 3071     Classics, Science Fiction, Thriller
# 3072             Anime, Drama, International
#
#                                             description
# 3070  Seventeen-year-old Paul is haunted by apocalyp...
# 3071  Rod Serling's seminal anthology series focused...
# 3072  The devastation is unleashed in the span of se...

# %% [markdown]
# ## Conhecendo nossos dados

# %%
df_hulu.shape
# Out:
# (3073, 12)

# %%
df_hulu.describe()
# Out:
#        cast  release_year
# count   0.0   3073.000000
# mean    NaN   2012.567524
# std     NaN     10.844069
# min     NaN   1923.000000
# 25%     NaN   2010.000000
# 50%     NaN   2016.000000
# 75%     NaN   2019.000000
# max     NaN   2021.000000

# %%
df_hulu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %%
df_hulu.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration         479
# listed_in          0
# description        4
# dtype: int64

# %%
df_hulu.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_hulu.nunique()
# Out:
# show_id         3073
# type               2
# title           3073
# director           3
# cast               0
# country          150
# date_added      1115
# release_year      72
# rating            88
# duration         135
# listed_in        442
# description     3057
# dtype: int64

# %%
# categorias do type
df_hulu['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# **Observações:**
# - Tratar as colunas nulas
# - Verificar se é relevante mudar o tipo de dados da coluna *date_added* e *duration*
# - Renomear coluna *listed_in* para **gender** e verificar como separar esses dados
# - Tratar dados ausentes
# - Filtrar os tipos de mídia
# - Alterar tipo **cast**

# %% [markdown]
# ## Tratamento dos dados

# %%
df_hulu_tratando = df_hulu.copy()

# %%
df_hulu_tratando = df_hulu_tratando.rename(columns={'listed_in': 'gender'})

# %% [markdown]
# Novo dataframe só com filmes e outro com TV Show

# %% [markdown]
# #### Movies

# %%
# filtrar os tipos de mídia
df_hulu_movies = df_hulu_tratando[df_hulu_tratando['type'] == 'Movie']

# %%
df_hulu_movies.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                     gender  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# 0  ​Comedian Ricky Velez bares it all with his ho...
# 1  Mark, a low end South London hitman recently r...
# 2  A hardened Arizona rancher tries to protect an...
# 3  A forest ranger and two survivalists with a cu...
# 4  Mankind's earliest settlers on the Martian fro...

# %%
df_hulu_movies.shape
# Out:
# (1484, 12)

# %% [markdown]
# Na coluna *duration* do df 'df_hulu_movies' remover caracteres, deixando apenas números e depois transformar

# %%
df_hulu_movies['duration'] = df_hulu_movies['duration'].str.replace(' min', '')
# Out:
# /tmp/ipython-input-17-3441114452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_movies['duration'] = df_hulu_movies['duration'].str.replace(' min', '')

# %%
# Observando os valores nulos
df_hulu_movies[df_hulu_movies['duration'].isnull()]
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                     Ricky Velez: Here's Everything
# 12       s13  Movie  Out of the Shadows: The Man Behind the Steele ...
# 15       s16  Movie  Showtime Championship Boxing: Lopez vs. Salido...
# 37       s38  Movie                  BELLATOR MMA: Kongo vs. Johnson 2
# 40       s41  Movie                                      In the Crease
# ...      ...    ...                                                ...
# 2951   s2952  Movie                                  All Saints (1998)
# 2955   s2956  Movie                                         Getting On
# 2958   s2959  Movie                                 (Sub) Ninja Scroll
# 2959   s2960  Movie                              Packed to the Rafters
# 2993   s2994  Movie                     Amy Winehouse: A Final Goodbye
#
#      director  cast         country         date_added  release_year  \
# 0         NaN   NaN             NaN   October 24, 2021          2021
# 12        NaN   NaN             NaN   October 18, 2021          2021
# 15        NaN   NaN             NaN   October 16, 2021          2011
# 37        NaN   NaN             NaN   October 13, 2021          2020
# 40        NaN   NaN             NaN   October 13, 2021          2020
# ...       ...   ...             ...                ...           ...
# 2951      NaN   NaN       Australia  February 19, 2014          1998
# 2955      NaN   NaN  United Kingdom    January 7, 2014          2009
# 2958      NaN   NaN           Japan  December 15, 2013          1993
# 2959      NaN   NaN       Australia   December 3, 2013          2008
# 2993      NaN   NaN  United Kingdom  December 13, 2012          2011
#
#           rating duration                              gender  \
# 0          TV-MA      NaN                    Comedy, Stand Up
# 12           NaN      NaN                                News
# 15           NaN      NaN                              Sports
# 37           NaN      NaN                              Sports
# 40           NaN      NaN                              Sports
# ...          ...      ...                                 ...
# 2951  12 Seasons      NaN                Drama, International
# 2955   3 Seasons      NaN       Comedy, International, Sitcom
# 2958      93 min      NaN  Action, Adult Animation, Adventure
# 2959   6 Seasons      NaN        Comedy, Drama, International
# 2993      71 min      NaN                Documentaries, Music
#
#                                             description
# 0     ​Comedian Ricky Velez bares it all with his ho...
# 12    George Stephanopoulos sits down with former MI...
# 15    Juan Manuel Lopez vs. Orlando Salido for the W...
# 37    Cheick Kongo vs. Tim Johnson battle in a histo...
# 40    Post-game analysis and highlight show airing e...
# ...                                                 ...
# 2951  All Saints is an Australian medical drama focu...
# 2955  Care for the elderly is the least glamorous ar...
# 2958  When Jubei saves a young ninja woman from the ...
# 2959  Packed to the Rafters is an Australian family-...
# 2993  A Final Goodbye is an intimate look into the l...
#
# [479 rows x 12 columns]

# %%
# Quantidade
df_hulu_movies[df_hulu_movies['duration'].isnull()].shape
# Out:
# (479, 12)

# %%
# Transformar str em float
df_hulu_movies['duration']= df_hulu_movies['duration'].astype(float)
# Out:
# /tmp/ipython-input-20-3701310663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_movies['duration']= df_hulu_movies['duration'].astype(float)

# %%
df_hulu_movies.describe()
# Out:
#        cast  release_year     duration
# count   0.0   1484.000000  1005.000000
# mean    NaN   2012.607143    98.266667
# std     NaN     12.142055    21.215423
# min     NaN   1923.000000     1.000000
# 25%     NaN   2012.000000    89.000000
# 50%     NaN   2017.000000    97.000000
# 75%     NaN   2019.000000   109.000000
# max     NaN   2021.000000   192.000000

# %%
df_hulu_movies['date_added'] = pd.to_datetime(df_hulu_movies['date_added'], errors='coerce')
# Out:
# /tmp/ipython-input-22-2774351008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_movies['date_added'] = pd.to_datetime(df_hulu_movies['date_added'], errors='coerce')

# %%
df_hulu_movies['date_added'] = df_hulu_movies['date_added'].dt.date
# Out:
# /tmp/ipython-input-23-3944206537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_movies['date_added'] = df_hulu_movies['date_added'].dt.date

# %%
# Transformar coluna cast em string
df_hulu_movies['cast'] = df_hulu_movies['cast'].astype(str)
# Out:
# /tmp/ipython-input-25-508658756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_movies['cast'] = df_hulu_movies['cast'].astype(str)

# %%
df_hulu_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1484 entries, 0 to 2993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1484 non-null   object
#  1   type          1484 non-null   object
#  2   title         1484 non-null   object
#  3   director      3 non-null      object
#  4   cast          1484 non-null   object
#  5   country       661 non-null    object
#  6   date_added    1484 non-null   object
#  7   release_year  1484 non-null   int64
#  8   rating        1194 non-null   object
#  9   duration      1005 non-null   float64
#  10  gender        1484 non-null   object
#  11  description   1481 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 183.0+ KB

# %% [markdown]
# #### Investigando os valores nulos

# %%
df_hulu_movies[df_hulu_movies['description'].isnull()]
# substituir 'country' pelo nome das outras variáveis vazias
# Out:
#      show_id   type        title director cast country  date_added  \
# 908     s909  Movie  Bart & Hahn      NaN  nan     NaN  2021-03-08
# 1158   s1159  Movie      UFC 252      NaN  nan     NaN  2020-11-25
# 1741   s1742  Movie          MLS      NaN  nan     NaN  2020-04-06
#
#       release_year rating  duration  gender description
# 908           2021    NaN       NaN  Sports         NaN
# 1158          2020  TV-14       NaN  Sports         NaN
# 1741          2009    NaN       NaN  Sports         NaN

# %% [markdown]
# #### TV Show

# %%
df_hulu_series = df_hulu_tratando[df_hulu_tratando['type'] == 'TV Show']

# %%
df_hulu_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1589 entries, 5 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1589 non-null   object
#  1   type          1589 non-null   object
#  2   title         1589 non-null   object
#  3   director      0 non-null      object
#  4   cast          0 non-null      float64
#  5   country       959 non-null    object
#  6   date_added    1561 non-null   object
#  7   release_year  1589 non-null   int64
#  8   rating        1359 non-null   object
#  9   duration      1589 non-null   object
#  10  gender        1589 non-null   object
#  11  description   1588 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 161.4+ KB

# %%
df_hulu_series['date_added'] = pd.to_datetime(df_hulu_series['date_added'], errors='coerce') #first
# Out:
# /tmp/ipython-input-38-420472522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_series['date_added'] = pd.to_datetime(df_hulu_series['date_added'], errors='coerce') #first

# %%
df_hulu_series['date_added'] = df_hulu_series['date_added'].dt.date # second
# Out:
# /tmp/ipython-input-39-3296202838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_series['date_added'] = df_hulu_series['date_added'].dt.date # second

# %%
df_hulu_series['duration'] = df_hulu_series['duration'].str.replace(' Seasons', '')
df_hulu_series['duration'] = df_hulu_series['duration'].str.replace(' Season', '')
# Out:
# /tmp/ipython-input-40-3845670907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_series['duration'] = df_hulu_series['duration'].str.replace(' Seasons', '')
# /tmp/ipython-input-40-3845670907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_series['duration'] = df_hulu_series['duration'].str.replace(' Season', '')

# %%
# transformar coluna duration em float
df_hulu_series['duration'] = df_hulu_series['duration'].astype(float)
# Out:
# /tmp/ipython-input-41-4169221918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_series['duration'] = df_hulu_series['duration'].astype(float)

# %%
# Transformando coluna cast em string
df_hulu_series['cast'] = df_hulu_series['cast'].astype(str)
# Out:
# /tmp/ipython-input-43-1528009063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hulu_series['cast'] = df_hulu_series['cast'].astype(str)

# %%
df_hulu_series.describe()
# Out:
#        release_year     duration
# count   1589.000000  1589.000000
# mean    2012.530522     2.720579
# std        9.476398     3.191016
# min     1933.000000     1.000000
# 25%     2010.000000     1.000000
# 50%     2015.000000     1.000000
# 75%     2019.000000     3.000000
# max     2021.000000    34.000000
